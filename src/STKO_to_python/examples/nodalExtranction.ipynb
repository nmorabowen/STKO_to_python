# %%
import numpy as np
from STKO_to_python import MPCODataSet

# %%
#filepath=r'D:\STKO Models\SW\Frame_Nm\cyclic_0.25'
filepath=r'D:\STKO Models\SW\Shell_Nm\005_15000a_025'
model=MPCODataSet(hdf5_directory=filepath, 
                  recorder_name='results')
# Out:
# No elements found.

# %%
model.print_summary()
# Out:
# File name: results
# Number of partitions: 4
# ------------------------------------------------------
# Number of model stages: 3
# Model stages: ['MODEL_STAGE[1]', 'MODEL_STAGE[2]', 'MODEL_STAGE[3]']
#   - MODEL_STAGE[1]
#   - MODEL_STAGE[2]
#   - MODEL_STAGE[3]
# ------------------------------------------------------
# Number of nodal results: 3
#   - DISPLACEMENT
#   - REACTION_FORCE
#   - REACTION_MOMENT
# ------------------------------------------------------
# Number of element results: 18
#   - section.fiber.cw
#   - section.fiber.stress
#   - section.fiber.strain
#   - equivalentPlasticStrain
#   - section.deformation
#   - material.stress
#   - material.cw
#   - section.fiber.equivalentPlasticStrain
#   - cw
#   - section.force
#   - damage
#   - force
#   - material.damage
#   - localForce
#   - material.strain
#   - material.equivalentPlasticStrain
#   - deformation
#   - section.fiber.damage
# Number of unique element types: 3
#   - 203-ASDShellQ4
#   - 204-ASDShellT3
#   - 64-DispBeamColumn3d
# ------------------------------------------------------
# General model information:
# Number of nodes: 2
# Number of element types: 3
# Number of elements: 2
# Number of steps: {'MODEL_STAGE[1]': 2, 'MODEL_STAGE[2]': 2, 'MODEL_STAGE[3]': 1373}
# Number of selection sets: 2

# %%
model.print_selection_set_info()
# Out:
# Selection set: 1
# Selection Set name: TopNode
# ------------------------------------------------------
# Selection set: 2
# Selection Set name: baseNodes
# ------------------------------------------------------

# %%
model.nodes.get_nodal_results(
    model_stage='MODEL_STAGE[3]',
    results_name='DISPLACEMENT',
    selection_set_id=1
)
# Out:
#                  val_1     val_2     val_3
# node_id step
# 1211    0     0.000030  0.000001 -0.000191
#         1     0.000331  0.000001 -0.000191
#         2     0.000631  0.000001 -0.000191
#         3     0.000932  0.000001 -0.000190
#         4     0.001233  0.000001 -0.000185
# ...                ...       ...       ...
#         1368 -0.019497  0.002150  0.003397
#         1369 -0.019827  0.002245  0.003449
#         1370 -0.020158  0.002314  0.003504
#         1371 -0.020489  0.002323  0.003554
#         1372 -0.020820  0.002324  0.003604
#
# [1373 rows x 3 columns]
